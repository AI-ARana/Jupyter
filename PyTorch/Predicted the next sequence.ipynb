# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
# Out:
# WARNING:tensorflow:From C:\Users\Anurag Rana\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Generate synthetic data
def generate_sequence(length):
    return np.array([i for i in range(length)])

sequence = generate_sequence(100)

# %%
# Prepare data for LSTM
def create_dataset(sequence, look_back=1):
    X, y = [], []
    for i in range(len(sequence) - look_back):
        X.append(sequence[i:(i + look_back)])
        y.append(sequence[i + look_back])
    return np.array(X), np.array(y)

look_back = 3
X, y = create_dataset(sequence, look_back)

# %%
# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\Anurag Rana\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Anurag Rana\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
model.fit(X, y, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Anurag Rana\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 97/97 - 1s - loss: 3196.1008 - 1s/epoch - 12ms/step
# Epoch 2/100
# 97/97 - 0s - loss: 2538.8848 - 123ms/epoch - 1ms/step
# Epoch 3/100
# 97/97 - 0s - loss: 2086.4746 - 106ms/epoch - 1ms/step
# Epoch 4/100
# 97/97 - 0s - loss: 1799.8381 - 118ms/epoch - 1ms/step
# Epoch 5/100
# 97/97 - 0s - loss: 1572.8341 - 115ms/epoch - 1ms/step
# Epoch 6/100
# 97/97 - 0s - loss: 1377.5095 - 104ms/epoch - 1ms/step
# Epoch 7/100
# 97/97 - 0s - loss: 1218.2480 - 120ms/epoch - 1ms/step
# Epoch 8/100
# 97/97 - 0s - loss: 1077.9752 - 112ms/epoch - 1ms/step
# Epoch 9/100
# 97/97 - 0s - loss: 958.4694 - 109ms/epoch - 1ms/step
# Epoch 10/100
# 97/97 - 0s - loss: 853.3978 - 138ms/epoch - 1ms/step
# Epoch 11/100
# 97/97 - 0s - loss: 761.5031 - 121ms/epoch - 1ms/step
# Epoch 12/100
# 97/97 - 0s - loss: 680.9095 - 117ms/epoch - 1ms/step
# Epoch 13/100
# 97/97 - 0s - loss: 610.9609 - 117ms/epoch - 1ms/step
# Epoch 14/100
# 97/97 - 0s - loss: 545.6421 - 105ms/epoch - 1ms/step
# Epoch 15/100
# 97/97 - 0s - loss: 488.5651 - 113ms/epoch - 1ms/step
# Epoch 16/100
# 97/97 - 0s - loss: 437.9737 - 124ms/epoch - 1ms/step
# Epoch 17/100
# 97/97 - 0s - loss: 393.1150 - 120ms/epoch - 1ms/step
# Epoch 18/100
# 97/97 - 0s - loss: 352.5829 - 102ms/epoch - 1ms/step
# Epoch 19/100
# 97/97 - 0s - loss: 317.1898 - 114ms/epoch - 1ms/step
# Epoch 20/100
# 97/97 - 0s - loss: 285.3712 - 114ms/epoch - 1ms/step
# Epoch 21/100
# 97/97 - 0s - loss: 255.7798 - 117ms/epoch - 1ms/step
# Epoch 22/100
# 97/97 - 0s - loss: 229.7977 - 101ms/epoch - 1ms/step
# Epoch 23/100
# 97/97 - 0s - loss: 206.4781 - 156ms/epoch - 2ms/step
# Epoch 24/100
# 97/97 - 0s - loss: 186.2953 - 126ms/epoch - 1ms/step
# Epoch 25/100
# 97/97 - 0s - loss: 167.1023 - 130ms/epoch - 1ms/step
# Epoch 26/100
# 97/97 - 0s - loss: 151.0359 - 133ms/epoch - 1ms/step
# Epoch 27/100
# 97/97 - 0s - loss: 136.7865 - 126ms/epoch - 1ms/step
# Epoch 28/100
# 97/97 - 0s - loss: 121.9833 - 103ms/epoch - 1ms/step
# Epoch 29/100
# 97/97 - 0s - loss: 109.5286 - 128ms/epoch - 1ms/step
# Epoch 30/100
# 97/97 - 0s - loss: 98.6546 - 114ms/epoch - 1ms/step
# Epoch 31/100
# 97/97 - 0s - loss: 88.5576 - 113ms/epoch - 1ms/step
# Epoch 32/100
# 97/97 - 0s - loss: 79.5853 - 99ms/epoch - 1ms/step
# Epoch 33/100
# 97/97 - 0s - loss: 71.7514 - 105ms/epoch - 1ms/step
# Epoch 34/100
# 97/97 - 0s - loss: 64.6456 - 112ms/epoch - 1ms/step
# Epoch 35/100
# 97/97 - 0s - loss: 58.0849 - 130ms/epoch - 1ms/step
# Epoch 36/100
# 97/97 - 0s - loss: 52.2198 - 121ms/epoch - 1ms/step
# Epoch 37/100
# 97/97 - 0s - loss: 46.9988 - 117ms/epoch - 1ms/step
# Epoch 38/100
# 97/97 - 0s - loss: 43.8381 - 118ms/epoch - 1ms/step
# Epoch 39/100
# 97/97 - 0s - loss: 38.6559 - 110ms/epoch - 1ms/step
# Epoch 40/100
# 97/97 - 0s - loss: 33.9270 - 101ms/epoch - 1ms/step
# Epoch 41/100
# 97/97 - 0s - loss: 30.5032 - 124ms/epoch - 1ms/step
# Epoch 42/100
# 97/97 - 0s - loss: 27.5400 - 116ms/epoch - 1ms/step
# Epoch 43/100
# 97/97 - 0s - loss: 24.6171 - 117ms/epoch - 1ms/step
# Epoch 44/100
# 97/97 - 0s - loss: 22.9289 - 117ms/epoch - 1ms/step
# Epoch 45/100
# 97/97 - 0s - loss: 19.8809 - 101ms/epoch - 1ms/step
# Epoch 46/100
# 97/97 - 0s - loss: 17.8607 - 123ms/epoch - 1ms/step
# Epoch 47/100
# 97/97 - 0s - loss: 16.7070 - 129ms/epoch - 1ms/step
# Epoch 48/100
# 97/97 - 0s - loss: 14.8843 - 117ms/epoch - 1ms/step
# Epoch 49/100
# 97/97 - 0s - loss: 13.7296 - 119ms/epoch - 1ms/step
# Epoch 50/100
# 97/97 - 0s - loss: 11.7883 - 122ms/epoch - 1ms/step
# Epoch 51/100
# 97/97 - 0s - loss: 10.3685 - 113ms/epoch - 1ms/step
# Epoch 52/100
# 97/97 - 0s - loss: 10.3498 - 122ms/epoch - 1ms/step
# Epoch 53/100
# 97/97 - 0s - loss: 9.3559 - 114ms/epoch - 1ms/step
# Epoch 54/100
# 97/97 - 0s - loss: 8.7070 - 114ms/epoch - 1ms/step
# Epoch 55/100
# 97/97 - 0s - loss: 6.9545 - 101ms/epoch - 1ms/step
# Epoch 56/100
# 97/97 - 0s - loss: 6.2933 - 108ms/epoch - 1ms/step
# Epoch 57/100
# 97/97 - 0s - loss: 5.5875 - 101ms/epoch - 1ms/step
# Epoch 58/100
# 97/97 - 0s - loss: 5.2152 - 108ms/epoch - 1ms/step
# Epoch 59/100
# 97/97 - 0s - loss: 4.4464 - 129ms/epoch - 1ms/step
# Epoch 60/100
# 97/97 - 0s - loss: 4.0229 - 113ms/epoch - 1ms/step
# Epoch 61/100
# 97/97 - 0s - loss: 4.9280 - 127ms/epoch - 1ms/step
# Epoch 62/100
# 97/97 - 0s - loss: 3.3101 - 115ms/epoch - 1ms/step
# Epoch 63/100
# 97/97 - 0s - loss: 4.4257 - 113ms/epoch - 1ms/step
# Epoch 64/100
# 97/97 - 0s - loss: 4.9975 - 119ms/epoch - 1ms/step
# Epoch 65/100
# 97/97 - 0s - loss: 3.0990 - 111ms/epoch - 1ms/step
# Epoch 66/100
# 97/97 - 0s - loss: 2.3177 - 96ms/epoch - 992us/step
# Epoch 67/100
# 97/97 - 0s - loss: 1.9731 - 113ms/epoch - 1ms/step
# Epoch 68/100
# 97/97 - 0s - loss: 1.7606 - 111ms/epoch - 1ms/step
# Epoch 69/100
# 97/97 - 0s - loss: 1.9816 - 111ms/epoch - 1ms/step
# Epoch 70/100
# 97/97 - 0s - loss: 1.5763 - 114ms/epoch - 1ms/step
# Epoch 71/100
# 97/97 - 0s - loss: 2.0307 - 105ms/epoch - 1ms/step
# Epoch 72/100
# 97/97 - 0s - loss: 2.4868 - 113ms/epoch - 1ms/step
# Epoch 73/100
# 97/97 - 0s - loss: 2.2152 - 114ms/epoch - 1ms/step
# Epoch 74/100
# 97/97 - 0s - loss: 1.0404 - 105ms/epoch - 1ms/step
# Epoch 75/100
# 97/97 - 0s - loss: 1.0128 - 126ms/epoch - 1ms/step
# Epoch 76/100
# 97/97 - 0s - loss: 1.1209 - 125ms/epoch - 1ms/step
# Epoch 77/100
# 97/97 - 0s - loss: 0.8371 - 105ms/epoch - 1ms/step
# Epoch 78/100
# 97/97 - 0s - loss: 1.5476 - 109ms/epoch - 1ms/step
# Epoch 79/100
# 97/97 - 0s - loss: 1.6304 - 114ms/epoch - 1ms/step
# Epoch 80/100
# 97/97 - 0s - loss: 1.3207 - 97ms/epoch - 1ms/step
# Epoch 81/100
# 97/97 - 0s - loss: 0.7599 - 119ms/epoch - 1ms/step
# Epoch 82/100
# 97/97 - 0s - loss: 0.6166 - 112ms/epoch - 1ms/step
# Epoch 83/100
# 97/97 - 0s - loss: 0.4260 - 124ms/epoch - 1ms/step
# Epoch 84/100
# 97/97 - 0s - loss: 0.8629 - 118ms/epoch - 1ms/step
# Epoch 85/100
# 97/97 - 0s - loss: 0.3637 - 103ms/epoch - 1ms/step
# Epoch 86/100
# 97/97 - 0s - loss: 0.4223 - 130ms/epoch - 1ms/step
# Epoch 87/100
# 97/97 - 0s - loss: 0.4807 - 111ms/epoch - 1ms/step
# Epoch 88/100
# 97/97 - 0s - loss: 1.7522 - 105ms/epoch - 1ms/step
# Epoch 89/100
# 97/97 - 0s - loss: 1.5945 - 107ms/epoch - 1ms/step
# Epoch 90/100
# 97/97 - 0s - loss: 1.0975 - 101ms/epoch - 1ms/step
# Epoch 91/100
# 97/97 - 0s - loss: 0.3847 - 109ms/epoch - 1ms/step
# Epoch 92/100
# 97/97 - 0s - loss: 0.2889 - 105ms/epoch - 1ms/step
# Epoch 93/100
# 97/97 - 0s - loss: 0.2640 - 116ms/epoch - 1ms/step
# Epoch 94/100
# 97/97 - 0s - loss: 0.2462 - 96ms/epoch - 989us/step
# Epoch 95/100
# 97/97 - 0s - loss: 0.5695 - 105ms/epoch - 1ms/step
# Epoch 96/100
# 97/97 - 0s - loss: 0.6262 - 106ms/epoch - 1ms/step
# Epoch 97/100
# 97/97 - 0s - loss: 0.3614 - 112ms/epoch - 1ms/step
# Epoch 98/100
# 97/97 - 0s - loss: 0.5695 - 115ms/epoch - 1ms/step
# Epoch 99/100
# 97/97 - 0s - loss: 0.6678 - 127ms/epoch - 1ms/step
# Epoch 100/100
# 97/97 - 0s - loss: 0.4328 - 99ms/epoch - 1ms/step

# %%
# Predict the next value in the sequence
last_sequence = sequence[-look_back:]  # Take the last `look_back` values
last_sequence = np.reshape(last_sequence, (1, look_back, 1))
predicted_value = model.predict(last_sequence)
print("Predicted next value in the sequence:", predicted_value[0][0])
# Out:
# 1/1 [==============================] - 0s 366ms/step
# Predicted next value in the sequence: 96.90417
